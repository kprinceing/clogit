# %%
import pandas as pd
import numpy as np
import googlemaps

# %%
map_api_key = 'AIzaSyCXqQPINi9qjFnZl4fG5gtCCS85aAwUw08'
gmaps = googlemaps.Client(key=map_api_key)

# %% [markdown]
# # Function Definitions

# %%
def clg_geo_code(row):
    geocode_result =gmaps.geocode(row['clg_string'])
    result   = geocode_result[0]
    city     = search_city(result)
    prov     = search_prov(result)
    lat, lng = search_longitude(result)
    return city,prov,lat, lng

# %%
def prov_geo_code(row):
    geocode_result =gmaps.geocode(row['prov_string'])
    result   = geocode_result[0]
    city     = search_city(result)
    prov     = search_prov(result)
    lat, lng = search_longitude(result)
    return city,prov,lat, lng

# %%
def search_city(result):
    city_name = ''
    for p in result['address_components']:
            if 'locality' in p['types']:
                city_name = p['long_name']
    if city_name == '': # 直辖市
        for p in result['address_components']:
            if 'administrative_area_level_1' in p['types']:
                city_name = p['long_name']
    return city_name

# %%
def search_prov(result):
    prov_name =''
    for p in result['address_components']:
            if 'administrative_area_level_1' in p['types']:
                prov_name = p['long_name']
    return prov_name

# %%
def search_longitude(result):
    lat  = np.nan
    lng = np.nan
    geometry = result['geometry']
    location = geometry['location']
    lat  = location['lat']
    lng  = location['lng']
    return lat, lng

# %%
def distance(row):
    prov_lat    = row['prov_lat']
    prov_lng    = row['prov_lng']   
    clg_lat     = row['clg_lat']
    clg_lng     = row['clg_lng']
    d = gmaps.distance_matrix((prov_lat, prov_lng),(clg_lat,clg_lng))
    if clg_lng>0:
        try:
            distance    = d['rows'][0]['elements'][0]['distance']['value'] 
        except:
            print(row['provid'],row['clg_string'])
            distance = np.nan
    else:
            distance = np.nan
    return distance

# %% [markdown]
# # Tests

# %%
# test these functions
geocode_result = gmaps.geocode('三峡大学')
result = geocode_result[0]
print(result)
print(search_city(result))
print(search_longitude(result))
# Out:
# {'address_components': [{'long_name': '8', 'short_name': '8', 'types': ['street_number']}, {'long_name': 'Daxue Road', 'short_name': 'Daxue Rd', 'types': ['route']}, {'long_name': 'Xiling Qu', 'short_name': 'Xiling Qu', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Yichang Shi', 'short_name': 'Yichang Shi', 'types': ['locality', 'political']}, {'long_name': 'Hubei Sheng', 'short_name': 'Hubei Sheng', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'China', 'short_name': 'CN', 'types': ['country', 'political']}, {'long_name': '443003', 'short_name': '443003', 'types': ['postal_code']}], 'formatted_address': '8 Daxue Rd, Xiling Qu, Yichang Shi, Hubei Sheng, China, 443003', 'geometry': {'location': {'lat': 30.72048199999999, 'lng': 111.318127}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 30.72183098029149, 'lng': 111.3194759802915}, 'southwest': {'lat': 30.7191330197085, 'lng': 111.3167780197085}}}, 'place_id': 'ChIJmTbtTZyagzYRU05MY6d1_4A', 'plus_code': {'compound_code': 'P8C9+57 Xiling, Yichang, Hubei, China', 'global_code': '8P2HP8C9+57'}, 'types': ['establishment', 'point_of_interest', 'university']}
# Yichang Shi
# (30.72048199999999, 111.318127)

# %%
d = gmaps.distance_matrix((30.720482,111.318127),(31.189043,121.450955))
print(d)
print(d['rows'][0]['elements'][0]['distance']['value'])
# Out:
# {'destination_addresses': ['China, Shanghai Shi, Xuhui Qu, Lingling Rd, 531号甲 邮政编码: 200000'], 'origin_addresses': ['Yun Shen Lu, Xiling Qu, Yichang Shi, Hubei Sheng, China, 443003'], 'rows': [{'elements': [{'distance': {'text': '1,147 km', 'value': 1146639}, 'duration': {'text': '12 hours 9 mins', 'value': 43755}, 'status': 'OK'}]}], 'status': 'OK'}
# 1146639

# %% [markdown]
# # Apply to dataset

# %% [markdown]
# ## Gen college locations DF

# %%
df = pd.read_stata('C:/Users/yan/Dropbox/college_entrance_exam/data/ncee_rank.dta')
clg= pd.DataFrame(df['clg_num'].unique().astype(str))
clg.rename(columns={0:'clg_string'},inplace=True)
z =zip(*clg.apply(clg_geo_code,axis=1)) #store the returned tuples as a zipped object
clg['clg_city'],clg['clg_prov'],clg['clg_lat'], clg['clg_lng']=z # assign the zipped object to dataframe columns
print(clg.head(5))
clg.to_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/clg_geocode.xlsx') #export to excel and manually check errors
# Out:
#   clg_string      clg_city      clg_prov    clg_lat     clg_lng
# 0       三峡大学   Yichang Shi   Hubei Sheng  30.720482  111.318127
# 1    上海中医药大学      Shanghai                31.189043  121.450955
# 2     上海交通大学  Shanghai Shi  Shanghai Shi  31.198357  121.435701
# 3    上海外国语大学  Shanghai Shi  Shanghai Shi  31.282177  121.483579
# 4       上海大学  Shanghai Shi  Shanghai Shi  31.278511  121.457518

# %%
clg= pd.read_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/clg_geocode_correct.xlsx') #export to excel and manually check errors

# %% [markdown]
# ## Gen province locations DF

# %%
prov = pd.read_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/prov.xlsx')
z =zip(*prov.apply(prov_geo_code,axis=1)) #store the returned tuples as a zipped object
prov['prov_city'],prov['prov_prov'],prov['prov_lat'], prov['prov_lng'] = z # assign the zipped object to dataframe columns
prov.rename(columns={'prov':'provid'},inplace=True)
prov['provid'] = prov['provid'].astype('int64') # convert provid to integer type
prov.head(5)
# Out:
#    provid   prov_string       prov_city       prov_prov   prov_lat    prov_lng
# 0      11     北京市               Beijing         Beijing  39.904200  116.407396
# 1      12     天津市               Tianjin         Tianjin  39.343357  117.361648
# 2      13     河北省                 Hebei           Hebei  37.895659  114.904221
# 3      14     山西省                Shanxi          Shanxi  37.242565  111.856859
# 4      15     内蒙古自治区     Inner Mongolia  Inner Mongolia  43.378220  115.059482

# %%
prov['provid'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Gen clg and provinces DF

# %%
prov_clg =df[['score','provid','clg_num']].groupby(by=['provid','clg_num']).count().reset_index() # transform to a dataframe with the number of provinces * the number of colleges
prov_clg.drop(labels=['score'],axis=1,inplace=True)
prov_clg['provid'].astype('str',inplace=True) # convert provid to integer type
prov_clg.rename(columns={'clg_num':'clg_string'}, inplace=True)
prov_clg.head()
# Out:
#    provid clg_string
# 0      11       三峡大学
# 1      11    上海中医药大学
# 2      11     上海交通大学
# 3      11    上海外国语大学
# 4      11       上海大学

# %%
# merge the provid with provstring
temp =prov_clg.merge(prov,how='left',on='provid')
# merge with the clg df
prov_clg_geo = temp.merge(clg,how='left',on='clg_string')

# %%
print(prov_clg_geo[(prov_clg_geo['prov_lng']<0) | (prov_clg_geo['prov_lng']==np.nan)].count()) # check if the lat and lng are positive and non-missin
print(prov_clg_geo[(prov_clg_geo['prov_lat']<0) | (prov_clg_geo['prov_lat']==np.nan)].count())     
print(prov_clg_geo[(prov_clg_geo['clg_lat']<0) | (prov_clg_geo['clg_lat']==np.nan)].count())
prov_clg_geo[(prov_clg_geo['clg_lng']<0) | (prov_clg_geo['clg_lng']==np.nan)].count()
# Out:
# provid         0
# clg_string     0
# prov_string    0
# prov_city      0
# prov_prov      0
# prov_lat       0
# prov_lng       0
# clg_city       0
# clg_prov       0
# clg_lat        0
# clg_lng        0
# dtype: int64
# provid         0
# clg_string     0
# prov_string    0
# prov_city      0
# prov_prov      0
# prov_lat       0
# prov_lng       0
# clg_city       0
# clg_prov       0
# clg_lat        0
# clg_lng        0
# dtype: int64
# provid         0
# clg_string     0
# prov_string    0
# prov_city      0
# prov_prov      0
# prov_lat       0
# prov_lng       0
# clg_city       0
# clg_prov       0
# clg_lat        0
# clg_lng        0
# dtype: int64
# provid         0
# clg_string     0
# prov_string    0
# prov_city      0
# prov_prov      0
# prov_lat       0
# prov_lng       0
# clg_city       0
# clg_prov       0
# clg_lat        0
# clg_lng        0
# dtype: int64

# %%
prov_clg_geo.to_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/prov_clg_geo.xlsx') #export to excel and manually check errors

# %% [markdown]
# ## Calculate distance

# %%
prov_clg_geo = pd.read_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/prov_clg_geo.xlsx')

# %%
# apply the distance function on this dataframe
prov_clg_geo['distance'] = prov_clg_geo.apply(distance,axis=1)
# Out:
# 15 三峡大学
# 15 上海中医药大学
# 15 上海交通大学
# 15 上海外国语大学
# 15 上海大学
# 15 上海工程技术大学
# 15 上海师范大学
# 15 上海海事大学
# 15 上海海洋大学
# 15 上海理工大学
# 15 上海电力学院
# 15 上海电机学院
# 15 上海立信会计学院
# 15 上海第二工业大学
# 15 上海财经大学
# 15 东北农业大学
# 15 东北大学
# 15 东北师范大学
# 15 东北林业大学
# 15 东北电力大学
# 15 东北石油大学
# 15 东北财经大学
# 15 东华大学
# 15 东华理工大学
# 15 东南大学
# 15 东莞理工学院
# 15 中北大学
# 15 中南大学
# 15 中南林业科技大学
# 15 中南民族大学
# 15 中南财经政法大学
# 15 中原工学院
# 15 中国人民大学
# 15 中国传媒大学
# 15 中国农业大学
# 15 中国医科大学
# 15 中国政法大学
# 15 中国民航大学
# 15 中国海洋大学
# 15 中国矿业大学
# 15 中国科学技术大学
# 15 中国药科大学
# 15 中央民族大学
# 15 中央财经大学
# 15 中山大学
# 15 临沂大学
# 15 丽水学院
# 15 乐山师范学院
# 15 云南农业大学
# 15 云南大学
# 15 云南师范大学
# 15 五邑大学
# 15 井冈山大学
# 15 佛山科学技术学院
# 15 佳木斯大学
# 15 信阳师范学院
# 15 兰州交通大学
# 15 兰州城市学院
# 15 兰州大学
# 15 兰州理工大学
# 15 内江师范学院
# 15 内蒙古大学
# 15 内蒙古工业大学
# 15 内蒙古科技大学
# 15 北京中医药大学
# 15 北京交通大学
# 15 北京体育大学
# 15 北京信息科技大学
# 15 北京化工大学
# 15 北京协和医学院
# 15 北京印刷学院
# 15 北京大学
# 15 北京工业大学
# 15 北京工商大学
# 15 北京师范大学
# 15 北京服装学院
# 15 北京林业大学
# 15 北京物资学院
# 15 北京理工大学
# 15 北京石油化工学院
# 15 北京科技大学
# 15 北京联合大学
# 15 北京航空航天大学
# 15 北京邮电大学
# 15 北华大学
# 15 北方工业大学
# 15 北方民族大学
# 15 华东交通大学
# 15 华东师范大学
# 15 华东理工大学
# 15 华中农业大学
# 15 华中师范大学
# 15 华中科技大学
# 15 华侨大学
# 15 华北科技学院
# 15 华南农业大学
# 15 华南师范大学
# 15 华南理工大学
# 15 南京中医药大学
# 15 南京信息工程大学
# 15 南京农业大学
# 15 南京医科大学
# 15 南京大学
# 15 南京工业大学
# 15 南京师范大学
# 15 南京晓庄学院
# 15 南京林业大学
# 15 南京理工大学
# 15 南京航空航天大学
# 15 南京财经大学
# 15 南京邮电大学
# 15 南华大学
# 15 南开大学
# 15 南方医科大学
# 15 南昌大学
# 15 南昌工程学院
# 15 南昌航空大学
# 15 南通大学
# 15 南阳师范学院
# 15 南阳理工学院
# 15 厦门大学
# 15 厦门理工学院
# 15 合肥工业大学
# 15 吉林农业大学
# 15 吉林化工学院
# 15 吉林医药学院
# 15 吉林大学
# 15 吉林师范大学
# 15 吉首大学
# 15 同济大学
# 15 周口师范学院
# 15 咸阳师范学院
# 15 哈尔滨医科大学
# 15 哈尔滨商业大学
# 15 哈尔滨学院
# 15 哈尔滨工业大学
# 15 哈尔滨工程大学
# 15 哈尔滨师范大学
# 15 哈尔滨理工大学
# 15 唐山学院
# 15 唐山师范学院
# 15 商丘师范学院
# 15 嘉兴学院
# 15 嘉应学院
# 15 四川农业大学
# 15 四川大学
# 15 四川师范大学
# 15 四川文理学院
# 15 四川理工学院
# 15 复旦大学
# 15 大连交通大学
# 15 大连医科大学
# 15 大连大学
# 15 大连工业大学
# 15 大连海事大学
# 15 大连海洋大学
# 15 大连理工大学
# 15 天津中医药大学
# 15 天津农学院
# 15 天津医科大学
# 15 天津商业大学
# 15 天津大学
# 15 天津工业大学
# 15 天津师范大学
# 15 天津理工大学
# 15 天津科技大学
# 15 天津职业技术师范大学
# 15 天津财经大学
# 15 太原工业学院
# 15 太原师范学院
# 15 太原理工大学
# 15 太原科技大学
# 15 宁夏大学
# 15 宁波大学
# 15 宁波工程学院
# 15 安徽农业大学
# 15 安徽医科大学
# 15 安徽大学
# 15 安徽工业大学
# 15 安徽师范大学
# 15 安徽理工大学
# 15 安徽科技学院
# 15 安阳工学院
# 15 安阳师范学院
# 15 宝鸡文理学院
# 15 对外经济贸易大学
# 15 山东中医药大学
# 15 山东交通学院
# 15 山东农业大学
# 15 山东大学
# 15 山东工商学院
# 15 山东师范大学
# 15 山东建筑大学
# 15 山东理工大学
# 15 山东科技大学
# 15 山西农业大学
# 15 山西医科大学
# 15 山西大同大学
# 15 山西大学
# 15 山西师范大学
# 15 山西财经大学
# 15 川北医学院
# 15 常州大学
# 15 常熟理工学院
# 15 平顶山学院
# 15 广东外语外贸大学
# 15 广东工业大学
# 15 广东技术师范学院
# 15 广东海洋大学
# 15 广州中医药大学
# 15 广州大学
# 15 广西医科大学
# 15 广西大学
# 15 广西师范大学
# 15 广西师范学院
# 15 广西民族大学
# 15 廊坊师范学院
# 15 延安大学
# 15 延边大学
# 15 徐州工程学院
# 15 忻州师范学院
# 15 怀化学院
# 15 惠州学院
# 15 成都中医药大学
# 15 成都医学院
# 15 成都学院
# 15 成都理工大学
# 15 扬州大学
# 15 承德医学院
# 15 新乡医学院
# 15 新疆医科大学
# 15 新疆大学
# 15 昆明学院
# 15 昆明理工大学
# 15 暨南大学
# 15 曲阜师范大学
# 15 曲靖师范学院
# 15 杭州师范大学
# 15 杭州电子科技大学
# 15 桂林医学院
# 15 桂林理工大学
# 15 桂林电子科技大学
# 15 榆林学院
# 15 武汉大学
# 15 武汉工程大学
# 15 武汉理工大学
# 15 武汉科技大学
# 15 汕头大学
# 15 江南大学
# 15 江汉大学
# 15 江苏大学
# 15 江苏科技大学
# 15 江西农业大学
# 15 江西师范大学
# 15 江西理工大学
# 15 江西财经大学
# 15 沈阳农业大学
# 15 沈阳医学院
# 15 沈阳大学
# 15 沈阳工业大学
# 15 沈阳工程学院
# 15 沈阳师范大学
# 15 沈阳建筑大学
# 15 沈阳理工大学
# 15 沈阳航空航天大学
# 15 沈阳药科大学
# 15 河北农业大学
# 15 河北北方学院
# 15 河北医科大学
# 15 河北大学
# 15 河北工业大学
# 15 河北工程大学
# 15 河北师范大学
# 15 河北科技大学
# 15 河北经贸大学
# 15 河南农业大学
# 15 河南大学
# 15 河南工业大学
# 15 河南工程学院
# 15 河南师范大学
# 15 河南理工大学
# 15 河南科技大学
# 15 河南科技学院
# 15 河海大学
# 15 泉州师范学院
# 15 泰山医学院
# 15 泰山学院
# 15 洛阳师范学院
# 15 洛阳理工学院
# 15 济南大学
# 15 济宁医学院
# 15 浙江万里学院
# 15 浙江中医药大学
# 15 浙江农林大学
# 15 浙江大学
# 15 浙江工业大学
# 15 浙江工商大学
# 15 浙江师范大学
# 15 浙江理工大学
# 15 浙江科技学院
# 15 海南医学院
# 15 海南大学
# 15 海南师范大学
# 15 淮北师范大学
# 15 淮海工学院
# 15 淮阴工学院
# 15 淮阴师范学院
# 15 深圳大学
# 15 清华大学
# 15 渤海大学
# 15 温州大学
# 15 渭南师范学院
# 15 湖北大学
# 15 湖北汽车工业学院
# 15 湖南农业大学
# 15 湖南商学院
# 15 湖南城市学院
# 15 湖南大学
# 15 湖南工业大学
# 15 湖南工学院
# 15 湖南工程学院
# 15 湖南师范大学
# 15 湖南文理学院
# 15 湖南理工学院
# 15 湖南科技大学
# 15 湖州师范学院
# 15 湘南学院
# 15 湘潭大学
# 15 滁州学院
# 15 滨州医学院
# 15 滨州学院
# 15 潍坊医学院
# 15 烟台大学
# 15 燕山大学
# 15 牡丹江医学院
# 15 牡丹江师范学院
# 15 玉林师范学院
# 15 玉溪师范学院
# 15 甘肃农业大学
# 15 电子科技大学
# 15 皖南医学院
# 15 皖西学院
# 15 盐城工学院
# 15 盐城师范学院
# 15 石家庄学院
# 15 石家庄铁道大学
# 15 石河子大学
# 15 福州大学
# 15 福建中医药大学
# 15 福建农林大学
# 15 福建医科大学
# 15 福建工程学院
# 15 福建师范大学
# 15 绍兴文理学院
# 15 聊城大学
# 15 肇庆学院
# 15 苏州大学
# 15 荆楚理工学院
# 15 莆田学院
# 15 蚌埠医学院
# 15 衡阳师范学院
# 15 西交利物浦大学
# 15 西北农林科技大学
# 15 西北大学
# 15 西北工业大学
# 15 西北师范大学
# 15 西华大学
# 15 西华师范大学
# 15 西南交通大学
# 15 西南大学
# 15 西南林业大学
# 15 西南民族大学
# 15 西南石油大学
# 15 西南科技大学
# 15 西南财经大学
# 15 西安交通大学
# 15 西安工程大学
# 15 西安建筑科技大学
# 15 西安理工大学
# 15 西安电子科技大学
# 15 西安石油大学
# 15 西安财经学院
# 15 西藏大学
# 15 许昌学院
# 15 贵州大学
# 15 贵州师范大学
# 15 贵州师范学院
# 15 赣南医学院
# 15 辽宁中医药大学
# 15 辽宁大学
# 15 辽宁工业大学
# 15 辽宁工程技术大学
# 15 辽宁师范大学
# 15 辽宁石油化工大学
# 15 辽宁科技大学
# 15 通化师范学院
# 15 遵义医学院
# 15 邵阳学院
# 15 郑州大学
# 15 郑州师范学院
# 15 郑州航空工业管理学院
# 15 重庆三峡学院
# 15 重庆交通大学
# 15 重庆医科大学
# 15 重庆大学
# 15 重庆工商大学
# 15 重庆师范大学
# 15 重庆科技学院
# 15 重庆邮电大学
# 15 金陵科技学院
# 15 长安大学
# 15 长春大学
# 15 长春工业大学
# 15 长春工程学院
# 15 长春理工大学
# 15 长江大学
# 15 长江师范学院
# 15 长沙学院
# 15 长沙理工大学
# 15 长治医学院
# 15 闽江学院
# 15 陕西师范大学
# 15 陕西科技大学
# 15 集美大学
# 15 青岛农业大学
# 15 青岛大学
# 15 青岛理工大学
# 15 青岛科技大学
# 15 青海大学
# 15 青海师范大学
# 15 鞍山师范学院
# 15 韩山师范学院
# 15 韶关学院
# 15 首都医科大学
# 15 首都师范大学
# 15 首都经济贸易大学
# 15 鲁东大学
# 15 黄冈师范学院
# 15 黄山学院
# 15 黄淮学院
# 15 黑龙江中医药大学
# 15 黑龙江八一农垦大学
# 15 黑龙江大学
# 15 齐齐哈尔医学院
# 15 齐齐哈尔大学
# 15 龙岩学院
# 63 三峡大学
# 63 上海中医药大学
# 63 上海交通大学
# 63 上海外国语大学
# 63 上海大学
# 63 上海工程技术大学
# 63 上海师范大学
# 63 上海海事大学
# 63 上海海洋大学
# 63 上海理工大学
# 63 上海电力学院
# 63 上海电机学院
# 63 上海立信会计学院
# 63 上海第二工业大学
# 63 上海财经大学
# 63 东北农业大学
# 63 东北大学
# 63 东北师范大学
# 63 东北林业大学
# 63 东北电力大学
# 63 东北石油大学
# 63 东北财经大学
# 63 东华大学
# 63 东华理工大学
# 63 东南大学
# 63 东莞理工学院
# 63 中北大学
# 63 中南大学
# 63 中南林业科技大学
# 63 中南民族大学
# 63 中南财经政法大学
# 63 中原工学院
# 63 中国人民大学
# 63 中国传媒大学
# 63 中国农业大学
# 63 中国医科大学
# 63 中国政法大学
# 63 中国民航大学
# 63 中国海洋大学
# 63 中国矿业大学
# 63 中国科学技术大学
# 63 中国药科大学
# 63 中央民族大学
# 63 中央财经大学
# 63 中山大学
# 63 临沂大学
# 63 丽水学院
# 63 乐山师范学院
# 63 云南农业大学
# 63 云南大学
# 63 云南师范大学
# 63 五邑大学
# 63 井冈山大学
# 63 佛山科学技术学院
# 63 佳木斯大学
# 63 信阳师范学院
# 63 兰州交通大学
# 63 兰州城市学院
# 63 兰州大学
# 63 兰州理工大学
# 63 内江师范学院
# 63 内蒙古大学
# 63 内蒙古工业大学
# 63 内蒙古科技大学
# 63 北京中医药大学
# 63 北京交通大学
# 63 北京体育大学
# 63 北京信息科技大学
# 63 北京化工大学
# 63 北京协和医学院
# 63 北京印刷学院
# 63 北京大学
# 63 北京工业大学
# 63 北京工商大学
# 63 北京师范大学
# 63 北京服装学院
# 63 北京林业大学
# 63 北京物资学院
# 63 北京理工大学
# 63 北京石油化工学院
# 63 北京科技大学
# 63 北京联合大学
# 63 北京航空航天大学
# 63 北京邮电大学
# 63 北华大学
# 63 北方工业大学
# 63 北方民族大学
# 63 华东交通大学
# 63 华东师范大学
# 63 华东理工大学
# 63 华中农业大学
# 63 华中师范大学
# 63 华中科技大学
# 63 华侨大学
# 63 华北科技学院
# 63 华南农业大学
# 63 华南师范大学
# 63 华南理工大学
# 63 南京中医药大学
# 63 南京信息工程大学
# 63 南京农业大学
# 63 南京医科大学
# 63 南京大学
# 63 南京工业大学
# 63 南京师范大学
# 63 南京晓庄学院
# 63 南京林业大学
# 63 南京理工大学
# 63 南京航空航天大学
# 63 南京财经大学
# 63 南京邮电大学
# 63 南华大学
# 63 南开大学
# 63 南方医科大学
# 63 南昌大学
# 63 南昌工程学院
# 63 南昌航空大学
# 63 南通大学
# 63 南阳师范学院
# 63 南阳理工学院
# 63 厦门大学
# 63 厦门理工学院
# 63 合肥工业大学
# 63 吉林农业大学
# 63 吉林化工学院
# 63 吉林医药学院
# 63 吉林大学
# 63 吉林师范大学
# 63 吉首大学
# 63 同济大学
# 63 周口师范学院
# 63 咸阳师范学院
# 63 哈尔滨医科大学
# 63 哈尔滨商业大学
# 63 哈尔滨学院
# 63 哈尔滨工业大学
# 63 哈尔滨工程大学
# 63 哈尔滨师范大学
# 63 哈尔滨理工大学
# 63 唐山学院
# 63 唐山师范学院
# 63 商丘师范学院
# 63 嘉兴学院
# 63 嘉应学院
# 63 四川农业大学
# 63 四川大学
# 63 四川师范大学
# 63 四川文理学院
# 63 四川理工学院
# 63 复旦大学
# 63 大连交通大学
# 63 大连医科大学
# 63 大连大学
# 63 大连工业大学
# 63 大连海事大学
# 63 大连海洋大学
# 63 大连理工大学
# 63 天津中医药大学
# 63 天津农学院
# 63 天津医科大学
# 63 天津商业大学
# 63 天津大学
# 63 天津工业大学
# 63 天津师范大学
# 63 天津理工大学
# 63 天津科技大学
# 63 天津职业技术师范大学
# 63 天津财经大学
# 63 太原工业学院
# 63 太原师范学院
# 63 太原理工大学
# 63 太原科技大学
# 63 宁夏大学
# 63 宁波大学
# 63 宁波工程学院
# 63 安徽农业大学
# 63 安徽医科大学
# 63 安徽大学
# 63 安徽工业大学
# 63 安徽师范大学
# 63 安徽理工大学
# 63 安徽科技学院
# 63 安阳工学院
# 63 安阳师范学院
# 63 宝鸡文理学院
# 63 对外经济贸易大学
# 63 山东中医药大学
# 63 山东交通学院
# 63 山东农业大学
# 63 山东大学
# 63 山东工商学院
# 63 山东师范大学
# 63 山东建筑大学
# 63 山东理工大学
# 63 山东科技大学
# 63 山西农业大学
# 63 山西医科大学
# 63 山西大同大学
# 63 山西大学
# 63 山西师范大学
# 63 山西财经大学
# 63 川北医学院
# 63 常州大学
# 63 常熟理工学院
# 63 平顶山学院
# 63 广东外语外贸大学
# 63 广东工业大学
# 63 广东技术师范学院
# 63 广东海洋大学
# 63 广州中医药大学
# 63 广州大学
# 63 广西医科大学
# 63 广西大学
# 63 广西师范大学
# 63 广西师范学院
# 63 广西民族大学
# 63 廊坊师范学院
# 63 延安大学
# 63 延边大学
# 63 徐州工程学院
# 63 忻州师范学院
# 63 怀化学院
# 63 惠州学院
# 63 成都中医药大学
# 63 成都医学院
# 63 成都学院
# 63 成都理工大学
# 63 扬州大学
# 63 承德医学院
# 63 新乡医学院
# 63 新疆医科大学
# 63 新疆大学
# 63 昆明学院
# 63 昆明理工大学
# 63 暨南大学
# 63 曲阜师范大学
# 63 曲靖师范学院
# 63 杭州师范大学
# 63 杭州电子科技大学
# 63 桂林医学院
# 63 桂林理工大学
# 63 桂林电子科技大学
# 63 榆林学院
# 63 武汉大学
# 63 武汉工程大学
# 63 武汉理工大学
# 63 武汉科技大学
# 63 汕头大学
# 63 江南大学
# 63 江汉大学
# 63 江苏大学
# 63 江苏科技大学
# 63 江西农业大学
# 63 江西师范大学
# 63 江西理工大学
# 63 江西财经大学
# 63 沈阳农业大学
# 63 沈阳医学院
# 63 沈阳大学
# 63 沈阳工业大学
# 63 沈阳工程学院
# 63 沈阳师范大学
# 63 沈阳建筑大学
# 63 沈阳理工大学
# 63 沈阳航空航天大学
# 63 沈阳药科大学
# 63 河北农业大学
# 63 河北北方学院
# 63 河北医科大学
# 63 河北大学
# 63 河北工业大学
# 63 河北工程大学
# 63 河北师范大学
# 63 河北科技大学
# 63 河北经贸大学
# 63 河南农业大学
# 63 河南大学
# 63 河南工业大学
# 63 河南工程学院
# 63 河南师范大学
# 63 河南理工大学
# 63 河南科技大学
# 63 河南科技学院
# 63 河海大学
# 63 泉州师范学院
# 63 泰山医学院
# 63 泰山学院
# 63 洛阳师范学院
# 63 洛阳理工学院
# 63 济南大学
# 63 济宁医学院
# 63 浙江万里学院
# 63 浙江中医药大学
# 63 浙江农林大学
# 63 浙江大学
# 63 浙江工业大学
# 63 浙江工商大学
# 63 浙江师范大学
# 63 浙江理工大学
# 63 浙江科技学院
# 63 海南医学院
# 63 海南大学
# 63 海南师范大学
# 63 淮北师范大学
# 63 淮海工学院
# 63 淮阴工学院
# 63 淮阴师范学院
# 63 深圳大学
# 63 清华大学
# 63 渤海大学
# 63 温州大学
# 63 渭南师范学院
# 63 湖北大学
# 63 湖北汽车工业学院
# 63 湖南农业大学
# 63 湖南商学院
# 63 湖南城市学院
# 63 湖南大学
# 63 湖南工业大学
# 63 湖南工学院
# 63 湖南工程学院
# 63 湖南师范大学
# 63 湖南文理学院
# 63 湖南理工学院
# 63 湖南科技大学
# 63 湖州师范学院
# 63 湘南学院
# 63 湘潭大学
# 63 滁州学院
# 63 滨州医学院
# 63 滨州学院
# 63 潍坊医学院
# 63 烟台大学
# 63 燕山大学
# 63 牡丹江医学院
# 63 牡丹江师范学院
# 63 玉林师范学院
# 63 玉溪师范学院
# 63 甘肃农业大学
# 63 电子科技大学
# 63 皖南医学院
# 63 皖西学院
# 63 盐城工学院
# 63 盐城师范学院
# 63 石家庄学院
# 63 石家庄铁道大学
# 63 石河子大学
# 63 福州大学
# 63 福建中医药大学
# 63 福建农林大学
# 63 福建医科大学
# 63 福建工程学院
# 63 福建师范大学
# 63 绍兴文理学院
# 63 聊城大学
# 63 肇庆学院
# 63 苏州大学
# 63 荆楚理工学院
# 63 莆田学院
# 63 蚌埠医学院
# 63 衡阳师范学院
# 63 西交利物浦大学
# 63 西北农林科技大学
# 63 西北大学
# 63 西北工业大学
# 63 西北师范大学
# 63 西华大学
# 63 西华师范大学
# 63 西南交通大学
# 63 西南大学
# 63 西南林业大学
# 63 西南民族大学
# 63 西南石油大学
# 63 西南科技大学
# 63 西南财经大学
# 63 西安交通大学
# 63 西安工程大学
# 63 西安建筑科技大学
# 63 西安理工大学
# 63 西安电子科技大学
# 63 西安石油大学
# 63 西安财经学院
# 63 西藏大学
# 63 许昌学院
# 63 贵州大学
# 63 贵州师范大学
# 63 贵州师范学院
# 63 赣南医学院
# 63 辽宁中医药大学
# 63 辽宁大学
# 63 辽宁工业大学
# 63 辽宁工程技术大学
# 63 辽宁师范大学
# 63 辽宁石油化工大学
# 63 辽宁科技大学
# 63 通化师范学院
# 63 遵义医学院
# 63 邵阳学院
# 63 郑州大学
# 63 郑州师范学院
# 63 郑州航空工业管理学院
# 63 重庆三峡学院
# 63 重庆交通大学
# 63 重庆医科大学
# 63 重庆大学
# 63 重庆工商大学
# 63 重庆师范大学
# 63 重庆科技学院
# 63 重庆邮电大学
# 63 金陵科技学院
# 63 长安大学
# 63 长春大学
# 63 长春工业大学
# 63 长春工程学院
# 63 长春理工大学
# 63 长江大学
# 63 长江师范学院
# 63 长沙学院
# 63 长沙理工大学
# 63 长治医学院
# 63 闽江学院
# 63 陕西师范大学
# 63 陕西科技大学
# 63 集美大学
# 63 青岛农业大学
# 63 青岛大学
# 63 青岛理工大学
# 63 青岛科技大学
# 63 青海大学
# 63 青海师范大学
# 63 鞍山师范学院
# 63 韩山师范学院
# 63 韶关学院
# 63 首都医科大学
# 63 首都师范大学
# 63 首都经济贸易大学
# 63 鲁东大学
# 63 黄冈师范学院
# 63 黄山学院
# 63 黄淮学院
# 63 黑龙江中医药大学
# 63 黑龙江八一农垦大学
# 63 黑龙江大学
# 63 齐齐哈尔医学院
# 63 齐齐哈尔大学
# 63 龙岩学院

# %%
prov_clg_geo.head()
# Out:
#    provid clg_string   prov_string prov_city prov_prov  prov_lat    prov_lng  \
# 0      11       三峡大学     北京市         Beijing   Beijing   39.9042  116.407396
# 1      11    上海中医药大学     北京市         Beijing   Beijing   39.9042  116.407396
# 2      11     上海交通大学     北京市         Beijing   Beijing   39.9042  116.407396
# 3      11    上海外国语大学     北京市         Beijing   Beijing   39.9042  116.407396
# 4      11       上海大学     北京市         Beijing   Beijing   39.9042  116.407396
#
#        clg_city      clg_prov    clg_lat     clg_lng   distance
# 0   Yichang Shi   Hubei Sheng  30.720482  111.318127  1298165.0
# 1  Shanghai Shi  Shanghai Shi  31.189043  121.450955  1218909.0
# 2  Shanghai Shi  Shanghai Shi  31.198357  121.435701  1219556.0
# 3  Shanghai Shi  Shanghai Shi  31.282177  121.483579  1212412.0
# 4  Shanghai Shi  Shanghai Shi  31.278511  121.457518  1206371.0

# %%
prov_clg_geo.to_excel('C:/Users/yan/Dropbox/college_entrance_exam/data/prov_clg_geo_finished.xlsx') #export to excel and manually check errors
